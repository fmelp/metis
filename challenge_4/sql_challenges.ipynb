# %% [markdown]
# ##Challenge 1

# %%
'''select player, count(*) Total
from
(select player1 as player
from us_men_2013
union all
select player2 as player from us_men_2013
union all
select player1 as player from aus_men_2013
union all
select player2 as player from aus_men_2013
union all
select player1 as player from wimbledon_men_2013
union all
select player2 as player from wimbledon_men_2013
union all
select player1 as player from aus_men_2013
union all
select player2 as player from aus_men_2013
) d
group by player
order by total desc;'''



'''
         player         | total 
------------------------+-------
 Rafael Nadal           |    21
 Stanislas Wawrinka     |    18
 Roger Federer          |    16
 Tomas Berdych          |    16
 Novak Djokovic         |    16
 Andy Murray            |    15
 David Ferrer           |    15
 Tommy Robredo          |    13
 Richard Gasquet        |    12
 Grigor Dimitrov        |    11
 Florian Mayer          |    11
 Denis Istomin          |    10
 Stephane Robert        |    10
 Kevin Anderson         |    10
 Roberto Bautista Agut  |    10
 Milos Raonic           |    10
 Kei Nishikori          |     9
 Mikhail Youzhny        |     9
 Feliciano Lopez        |     9
 Fabio Fognini          |     9
'''


'''
select player, count(*) Total
from
(select player1 as player
from us_women_2013
union all
select player2 as player from us_women_2013
union all
select player1 as player from french_women_2013
union all
select player2 as player from french_women_2013
union all
select player1 as player from wimbledon_women_2013
union all
select player2 as player from wimbledon_women_2013
union all
select player1 as player from aus_ladies_2013
union all
select player2 as player from aus_ladies_2013
) d
group by player
order by total desc;
'''


'''
           player           | total 
----------------------------+-------
 Agnieszka Radwanska        |    17
 Dominika Cibulkova         |    16
 Na Li                      |    16
 Victoria Azarenka          |    16
 Serena Williams            |    15
 Maria Sharapova            |    15
 Ana Ivanovic               |    14
 Eugenie Bouchard           |    14
 Jelena Jankovic            |    13
 Angelique Kerber           |    12
 Sloane Stephens            |    12
 Simona Halep               |    11
 Flavia Pennetta            |    11
 Carla Suarez Navarro       |    10
 Garbine Muguruza           |    10
 Ekaterina Makarova         |     9
 Samantha Stosur            |     9
 Alize Cornet               |     9
 Jie Zheng                  |     9
 Elina Svitolina            |     8
 A.Radwanska                |     8
 Sara Errani                |     8
 Anastasia Pavlyuchenkova   |     8
'''
# Out:
# '\n           player           | total \n----------------------------+-------\n Agnieszka Radwanska        |    17\n Dominika Cibulkova         |    16\n Na Li                      |    16\n Victoria Azarenka          |    16\n Serena Williams            |    15\n Maria Sharapova            |    15\n Ana Ivanovic               |    14\n Eugenie Bouchard           |    14\n Jelena Jankovic            |    13\n Angelique Kerber           |    12\n Sloane Stephens            |    12\n Simona Halep               |    11\n Flavia Pennetta            |    11\n Carla Suarez Navarro       |    10\n Garbine Muguruza           |    10\n Ekaterina Makarova         |     9\n Samantha Stosur            |     9\n Alize Cornet               |     9\n Jie Zheng                  |     9\n Elina Svitolina            |     8\n A.Radwanska                |     8\n Sara Errani                |     8\n Anastasia Pavlyuchenkova   |     8\n'

# %% [markdown]
# ##Challenge 2

# %%
print 'men: Rafa Nadal'
print 'women: Agnieszka Radwanska'
# Out:
# men: Rafa Nadal
# women: Agnieszka Radwanska

# %% [markdown]
# ##Challenge 3

# %%
'''
MAKE A NEW TABLE
create table men_majors as (select *
from us_men_2013
union all
select * from aus_men_2013
union all
select * from wimbledon_men_2013 union all
select * from french_men_2013)
;
'''

'''
MAKE NEW TABLE
create table women_majors as (select *
from us_women_2013
union all
select * from aus_ladies_2013
union all
select * from wimbledon_women_2013 union all
select * from french_women_2013)
;
'''

'''
select max(fsp_1), player1, max(fsp_2), player2 from men_majors
group by player1, player2
order by max(fsp_1) desc;
tennis=# select max(fsp_1), player1, max(fsp_2), player2 from men_majors
group by player1, player2
order by max(fsp_1) desc;
'''


'''
 max |        player1         | max |         player2         
-----+------------------------+-----+-------------------------
  85 | V.Hanescu              |  70 | R.Federer
  84 | Rafael Nadal           |  74 | Daniel Brands
  83 | Roberto Bautista Agut  |  55 | Gilles Muller
  82 | Julien Benneteau       |  65 | Roger Federer
  82 | Roberto Bautista Agut  |  61 | Tim Smyczek
  79 | Roberto Bautista Agut  |  64 | Jeremy Chardy
  79 | Pablo Andujar          |  67 | Jerzy Janowicz
  78 | Juan Monaco            |  52 | Daniel Gimeno-Traver
  78 | B.Tomic                |  64 | S.Querrey
  78 | Daniel Gimeno-Traver   |  56 | Viktor Troicki
  78 | Rafael Nadal           |  67 | Fabio Fognini
  78 | Rafael Nadal           |  60 | Stanislas Wawrinka
  78 | J.Monaco               |  58 | B.Knittel
  77 | Nikolay Davydenko      |  60 | Lukasz Kubot

'''

'''
select max(fsp_1), player1, max(fsp_2), player2 from men_majors
group by player1, player2
order by max(fsp_2) desc;
tennis=# select max(fsp_1), player1, max(fsp_2), player2 from men_majors
group by player1, player2
order by max(fsp_2) desc;
'''


'''
 max |        player1         | max |         player2         
-----+------------------------+-----+-------------------------
  52 | Roger Federer          |  84 | Carlos Berlocq
  56 | Adrian Ungur           |  84 | Gael Monfils
  66 | Ivo Karlovic           |  83 | Ivan Dodig
  58 | Benoit Paire           |  83 | Roberto Bautista Agut
  70 | John Isner             |  83 | Gael Monfils
  69 | R.Gasquet              |  81 | B.Tomic
  77 | T.Robredo              |  79 | A.Bogomolov Jr.
  63 | Tommy Haas             |  78 | John Isner
  54 | Martin Klizan          |  78 | John Isner
  63 | Simone Bolelli         |  77 | Yen-Hsun Lu
  52 | Marcos Baghdatis       |  77 | Denis Istomin
  68 | J.Monaco               |  77 | R.Ram
  54 | F.Lopez                |  76 | T.Haas
  62 | Blaz Kavcic            |  76 | Roger Federer
  57 | Benoit Paire           |  75 | Lukasz Kubot
  68 | D.Ferrer               |  74 | M.Alund

'''


'''
select max(fsp_1), player1, max(fsp_2), player2 from women_majors
group by player1, player2
order by max(fsp_2) desc;
'''


'''
 max |          player1           | max |          player2           
-----+----------------------------+-----+----------------------------
  58 | F Pennetta                 |  93 | S Errani
  67 | Carla Suarez Navarro       |  91 | Sara Errani
  46 | Sabine Lisicki             |  89 | Sara Errani
  57 | Francesca Schiavone        |  88 | Victoria Azarenka
  64 | Yulia Putintseva           |  87 | Sara Errani
  62 | Jelena Jankovic            |  86 | Kurumi Nara
  52 | Arantxa Rus                |  85 | Sara Errani
  55 | Barbora Zahlavova Strycova |  85 | Victoria Azarenka
  70 | Agnieszka Radwanska        |  84 | Sara Errani
  69 | Sandra Zahlavova           |  83 | Annika Beck
  63 | J.Larsson                  |  82 | E.Makarova
  47 | C Vandeweghe               |  82 | C Suarez Navarro
  80 | Shahar Peer                |  82 | Monica Niculescu
  54 | M Kirilenko                |  81 | S Halep
  52 | J Jankovic                 |  81 | K Nara
  71 | Barbora Zahlavova Strycova |  80 | Bojana Jovanovski

'''


'''
select max(fsp_1), player1, max(fsp_2), player2 from women_majors
group by player1, player2
order by max(fsp_1) desc;
'''



'''
 max |          player1           | max |          player2           
-----+----------------------------+-----+----------------------------
  86 | Anabel Medina Garrigues    |  53 | Irina Falconi
  85 | M.Niculescu                |  68 | M.Barthel
  82 | Monica Niculescu           |  64 | Johanna Larsson
  82 | Vania King                 |  75 | Sloane Stephens
  81 | Varvara Lepchenko          |  65 | Angelique Kerber
  81 | Jie Zheng                  |  57 | Maria Sharapova
  80 | Na Li                      |  64 | Ekaterina Makarova
  80 | K Nara                     |  58 | S Cirstea
  80 | Shahar Peer                |  82 | Monica Niculescu
  79 | K.Date-Krumm               |  79 | A.Cadantu
  79 | Carla Suarez Navarro       |  69 | Vania King
  79 | Kimiko Date-Krumm          |  59 | Samantha Stosur
  79 | L.Arruabarrena             |  60 | L.Tsurenko
  79 | S.Stephens                 |  56 | P.Cetkovska

'''

print "V.Hanescuhas best first serve %ge, with 85"
print "S Errani best first serve %ge, with 93"
# Out:
# V.Hanescuhas best first serve %ge, with 85
# S Errani best first serve %ge, with 93

# %% [markdown]
# ##Challenge 4

# %%
'''
select player, unforced, total, 1.0*unforced/total as percentage
from
(select player1 as player, dbf_1 + ufe_1 as unforced, tpw_1 as total from men_majors
union all
select player2 as player, dbf_2 + ufe_2 as unforced, tpw_2 as total from men_majors
) d
where player = 'Rafael Nadal' or player = 'Stanislas Wawrinka' or player = 'Roger Federer'
;
'''

'''
       player       | unforced | total |       percentage       
--------------------+----------+-------+------------------------
 Roger Federer      |          |   103 |                       
 Stanislas Wawrinka |          |   103 |                       
 Roger Federer      |          |    94 |                       
