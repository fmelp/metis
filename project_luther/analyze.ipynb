# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
# %matplotlib inline
pd.options.mode.chained_assignment = None

data = pd.read_csv("~/Desktop/metis/project_luther/fixed_fuller_data_by_line_v1.csv")

data['budget'] = data['budget'].convert_objects(convert_numeric=True)

data['gross/budget'] = data['domestic_total_gross']/data['budget']

sorted_by_ratio = data.sort(columns='gross/budget', ascending=False)

show = sorted_by_ratio[['movie_title', 'gross/budget', 'genre', 'director']]

print show.head(100)
# Out:
#                                   movie_title     gross/budget  \
# 3                                   Airplane!  23843868.285714
# 264                       Terms of Endearment  13552936.125000
# 92                    Raiders of the Lost Ark  11790112.500000
# 0                     The Empire Strikes Back  11633223.611111
# 476                      The Care Bears Movie  11467311.000000
# 442                        Back to the Future  11084724.315789
# 272                            Risky Business  10248673.709677
# 117                           Private Lessons   9385357.142857
# 177                                   Tootsie   8438095.238095
# 263                        Return of the Jedi   7771803.600000
# 356                              Ghostbusters   7641432.966667
# 714                                     Twins   7462559.200000
# 798                                    Batman   7176826.400000
# 181           Star Trek II: The Wrath of Khan   7045800.267857
# 570                        A Room with a View   6988881.333333
# 710                                  Rain Man   6913017.400000
# 357      Indiana Jones and the Temple of Doom   6423938.250000
# 372                            The Terminator   5995500.000000
# 20                            Dressed to Kill   4907538.461538
# 537             Down and Out in Beverly Hills   4438158.928571
# 632                                   Robocop   4109590.846154
# 628                                  Predator   3982369.866667
# 763  Halloween 4: The Return of Michael Myers   3553751.400000
# 186                               First Blood   3147526.933333
# 715                                  Die Hard   2964601.857143
# 801                Back to the Future Part II   2961250.050000
# 13                                The Shining   2316703.894737
# 711                   Who Framed Roger Rabbit   2235033.857143
# 94                                Superman II   2003439.000000
# 193                                      Tron   1941176.470588
# ..                                        ...              ...
# 25                               Bronco Billy              NaN
# 26                                Raging Bull              NaN
# 27                                     Xanadu              NaN
# 28                            American Gigolo              NaN
# 29                               My Bodyguard              NaN
# 30                                    The Fog              NaN
# 31                                       Fame              NaN
# 32                                       Tess              NaN
# 33                             Altered States              NaN
# 34                          Song of the South              NaN
# 35                                   Cruising              NaN
# 36                                The Octagon              NaN
# 37                             The Aristocats              NaN
# 38                           Honeysuckle Rose              NaN
# 39                        Herbie Goes Bananas              NaN
# 40                                  Rough Cut              NaN
# 41                        The Final Countdown              NaN
# 42                                 The Hunter              NaN
# 43                              Hero at Large              NaN
# 45         Close Encounters of the Third Kind              NaN
# 46                               First Family              NaN
# 47                                 Prom Night              NaN
# 48                           Oh, God! Book II              NaN
# 49                            The Competition              NaN
# 50                               Wholly Moses              NaN
# 51             Last Married Couple in America              NaN
# 53                         The Mirror Crack'd              NaN
# 54              The Last Flight of Noah's Ark              NaN
# 55         The Fiendish Plot of Dr. Fu Manchu              NaN
# 57                      The Hollywood Knights              NaN
#
#                                                  genre  \
# 3                                           ['Comedy']
# 264                                ['Comedy', 'Drama']
# 92                             ['Action', 'Adventure']
# 0         ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 476  ['Animation', 'Adventure', 'Comedy', 'Family',...
# 442                  ['Adventure', 'Comedy', 'Sci-Fi']
# 272            ['Comedy', 'Crime', 'Drama', 'Romance']
# 117                                         ['Comedy']
# 177                              ['Comedy', 'Romance']
# 263       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 356                              ['Comedy', 'Fantasy']
# 714                                         ['Comedy']
# 798                            ['Action', 'Adventure']
# 181  ['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Th...
# 570                               ['Drama', 'Romance']
# 710                                          ['Drama']
# 357                            ['Action', 'Adventure']
# 372                               ['Action', 'Sci-Fi']
# 20                             ['Mystery', 'Thriller']
# 537                                         ['Comedy']
# 632                   ['Action', 'Sci-Fi', 'Thriller']
# 628                   ['Action', 'Sci-Fi', 'Thriller']
# 763                             ['Horror', 'Thriller']
# 186                             ['Action', 'Thriller']
# 715                             ['Action', 'Thriller']
# 801                  ['Adventure', 'Comedy', 'Sci-Fi']
# 13                                          ['Horror']
# 711  ['Animation', 'Comedy', 'Crime', 'Family', 'Fa...
# 94                     ['Action', 'Romance', 'Sci-Fi']
# 193                  ['Action', 'Adventure', 'Sci-Fi']
# ..                                                 ...
# 25   ['Action', 'Adventure', 'Comedy', 'Drama', 'Ro...
# 26                     ['Biography', 'Drama', 'Sport']
# 27                   ['Fantasy', 'Musical', 'Romance']
# 28                      ['Crime', 'Drama', 'Thriller']
# 29                     ['Action', 'Drama', 'Thriller']
# 30                                          ['Horror']
# 31                       ['Drama', 'Music', 'Musical']
# 32                                ['Drama', 'Romance']
# 33   ['Drama', 'Fantasy', 'Horror', 'Sci-Fi', 'Thri...
# 34                    ['Animation', 'Family', 'Music']
# 35           ['Crime', 'Drama', 'Mystery', 'Thriller']
# 36          ['Action', 'Drama', 'Romance', 'Thriller']
# 37   ['Animation', 'Adventure', 'Comedy', 'Family',...
# 38                       ['Music', 'Romance', 'Drama']
# 39        ['Family', 'Adventure', 'Comedy', 'Fantasy']
# 40   ['Adventure', 'Comedy', 'Crime', 'Mystery', 'R...
# 41                                ['Action', 'Sci-Fi']
# 42                  ['Adventure', 'Drama', 'Thriller']
# 43                               ['Comedy', 'Romance']
# 45                                 ['Drama', 'Sci-Fi']
# 46                                          ['Comedy']
# 47                               ['Horror', 'Mystery']
# 48                               ['Comedy', 'Fantasy']
# 49                       ['Drama', 'Romance', 'Music']
# 50                    ['Comedy', 'Fantasy', 'History']
# 51                                          ['Comedy']
# 53                    ['Crime', 'Mystery', 'Thriller']
# 54                             ['Adventure', 'Family']
# 55                                          ['Comedy']
# 57                                          ['Comedy']
#
#                                              director
# 3    ['Jim Abrahams', 'David Zucker', 'Jerry Zucker']
# 264                               ['James L. Brooks']
# 92                               ['Steven Spielberg']
# 0                                  ['Irvin Kershner']
# 476                                     Arna Selznick
# 442                               ['Robert Zemeckis']
# 272                                     Paul Brickman
# 117                                      Alan Myerson
# 177                                ['Sydney Pollack']
# 263                                  Richard Marquand
# 356                                  ['Ivan Reitman']
# 714                                  ['Ivan Reitman']
# 798                                    ['Tim Burton']
# 181                                    Nicholas Meyer
# 570                                   ['James Ivory']
# 710                                ['Barry Levinson']
# 357                              ['Steven Spielberg']
# 372                                 ['James Cameron']
# 20                                 ['Brian De Palma']
# 537                                     Paul Mazursky
# 632                                ['Paul Verhoeven']
# 628                            ['John Mc', 'Tiernan']
# 763                                  Dwight H. Little
# 186                                      Ted Kotcheff
# 715                            ['John Mc', 'Tiernan']
# 801                               ['Robert Zemeckis']
# 13                                    Stanley Kubrick
# 711                               ['Robert Zemeckis']
# 94               ['Richard Lester', 'Richard Donner']
# 193                              ['Steven Lisberger']
# ..                                                ...
# 25                                 ['Clint Eastwood']
# 26                                ['Martin Scorsese']
# 27                               ['Robert Greenwald']
# 28                                  ['Paul Schrader']
# 29                                         Tony Scott
# 30                                 ['John Carpenter']
# 31                                    ['Alan Parker']
# 32                                 ['Roman Polanski']
# 33                                    ['Ken Russell']
# 34                ['Wilfred Jackson', 'Harve Foster']
# 35                               ['William Friedkin']
# 36                                        Eric Karson
# 37                                Wolfgang Reitherman
# 38                                   Jerry Schatzberg
# 39                           ['Vincent Mc', 'Eveety']
# 40                    ['Don Siegel', 'Peter R. Hunt']
# 41                                         Don Taylor
# 42                                    Daniel Nettheim
# 43                                    Martin Davidson
# 45                                   Steven Spielberg
# 46   [' \n\n\n\nThe Spirit of Christmas\n\n\n\n', '']
# 47                                   Nelson McCormick
# 48                                      Gilbert Cates
# 49                                      Joel Oliansky
# 50                                      ['Gary Weis']
# 51                                      Gilbert Cates
# 53                                       Guy Hamilton
# 54                                    Charles Jarrott
# 55                 ['Piers Haggard', 'Richard Quine']
# 57                                       Floyd Mutrux
#
# [100 rows x 4 columns]
